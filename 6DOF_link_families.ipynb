# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load csv files

# %%
link_families1_6dof = pd.read_csv('6dof_link_families1.csv')
link_families2_6dof = pd.read_csv('6dof_link_families2.csv')
link_families3_6dof = pd.read_csv('6dof_link_families3.csv')
link_families4_6dof = pd.read_csv('6dof_link_families4.csv')
link_families5_6dof = pd.read_csv('6dof_link_families5.csv')

link_families_6dof = pd.concat([link_families1_6dof,link_families2_6dof,link_families3_6dof,
                                link_families4_6dof,link_families5_6dof])
link_families_6dof = link_families_6dof.drop(columns='Unnamed: 0')
link_families_6dof.rename(columns = {'Arm ID':'Arm_ID'}, inplace = True)
link_families_6dof
# Out:
#                                                   Arm_ID  Point number  \
# 0      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             1
# 1      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             2
# 2      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             3
# 3      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             4
# 4      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             5
# ...                                                  ...           ...
# 81805  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...             6
# 81806  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...             7
# 81807  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...             8
# 81808  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...             9
# 81809  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...            10
#
#        Move duration  Success  Manipulability - mu Manipulability - jacobian  \
# ...

# %% [markdown]
# # split arm name to features

# %%
# new data frame with split value columns
new = link_families_6dof["Arm_ID"].str.split("_", expand=True)

link_families_6dof["Joint1 type"] = new[1]
link_families_6dof["Joint1 axis"] = new[2]
link_families_6dof["Link1 length"] = new[3] + "." + new[4]

link_families_6dof["Joint2 type"] = new[5]
link_families_6dof["Joint2 axis"] = new[6]
link_families_6dof["Link2 length"] = new[7] + "." + new[8]

link_families_6dof["Joint3 type"] = new[9]
link_families_6dof["Joint3 axis"] = new[10]
link_families_6dof["Link3 length"] = new[11] + "." + new[12]

link_families_6dof["Joint4 type"] = new[13]
link_families_6dof["Joint4 axis"] = new[14]
link_families_6dof["Link4 length"] = new[15] + "." + new[16]

link_families_6dof["Joint5 type"] = new[17]
link_families_6dof["Joint5 axis"] = new[18]
link_families_6dof["Link5 length"] = new[19] + "." + new[20]

link_families_6dof["Joint6 type"] = new[21]
link_families_6dof["Joint6 axis"] = new[22]
link_families_6dof["Link6 length"] = new[23] + "." + new[24]

#all_6dof_data = grouped_all_6dof_data.drop(['Arm_ID'], axis=1)

pd.set_option('display.max_columns', 500)
link_families_6dof
# Out:
#                                                   Arm_ID  Point number  \
# 0      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             1
# 1      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             2
# 2      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             3
# 3      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             4
# 4      _roll_z_0_1_pris_z_0_1_pitch_y_0_1_pitch_x_0_7...             5
# ...                                                  ...           ...
# 81805  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...             6
# 81806  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...             7
# 81807  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...             8
# 81808  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...             9
# 81809  _roll_z_0_1_pris_y_0_7_roll_z_0_5_roll_y_0_3_r...            10
#
#        Move duration  Success  Manipulability - mu Manipulability - jacobian  \
# ...

# %% [markdown]
# # Group by Manipulator Configurations

# %%
'''Group by Manipulator Configuration
        Success_Rates - how many clusters the arm reached, normalized to 0-1.
        Min_Manipulability - the minimum manipulability value among 10 clusters
        Max_Manipulability - the maximum manipulability value among 10 clusters
        Manipulability_Rates - the avarage of the manipulability index
        MaxSum_Mid_joint_proximity - the maximum sum of mid joint matrix
'''
grouped_all = link_families_6dof.groupby(['Joint1 type','Joint1 axis', 'Joint2 type', 'Joint2 axis',
                                                      'Joint3 type', 'Joint3 axis', 'Joint4 type',
                                                      'Joint4 axis','Joint5 type', 'Joint5 axis','Joint6 type', 'Joint6 axis','Link1 length', 'Link2 length', 'Link3 length', 'Link4 length','Link5 length','Link6 length']).agg(
    Success_Rates=pd.NamedAgg(column="Success", aggfunc='mean'),
    Min_Manipulability=pd.NamedAgg(column='Manipulability - mu', aggfunc='min'),
    Max_Manipulability=pd.NamedAgg(column='Manipulability - mu', aggfunc='max'),
    Manipulability_Rates=pd.NamedAgg(column='Manipulability - mu', aggfunc='mean'),
    MaxSum_Mid_joint_proximity=pd.NamedAgg(column='Sum Mid joint proximity- all joints', aggfunc='max')).reset_index()


grouped_all
# Out:
#       Joint1 type Joint1 axis Joint2 type Joint2 axis Joint3 type Joint3 axis  \
# 0            roll           z       pitch           y       pitch           x
# 1            roll           z       pitch           y       pitch           x
# 2            roll           z       pitch           y       pitch           x
# 3            roll           z       pitch           y       pitch           x
# 4            roll           z       pitch           y       pitch           x
# ...           ...         ...         ...         ...         ...         ...
# 40927        roll           z        roll           y        roll           y
# 40928        roll           z        roll           y        roll           y
# 40929        roll           z        roll           y        roll           y
# 40930        roll           z        roll           y        roll           y
# 40931        roll           z        roll           y        roll           y
#
# ...

# %%
# problematic = pd.read_csv('problematic_link_families6dof.csv')
# problematic = problematic.drop(columns='Unnamed: 0')
# problematic
# Out:
#                                                Arm_ID  Point number  \
# 0   _roll_z_0_1_roll_y_0_3_pris_y_0_3_pitch_y_0_1_...           NaN
# 1   _roll_z_0_1_roll_y_0_3_pris_y_0_3_pitch_x_0_1_...           NaN
# 2   _roll_z_0_1_pris_y_0_3_roll_y_0_3_pris_z_0_1_p...           NaN
# 3   _roll_z_0_1_pris_y_0_1_roll_z_0_1_roll_y_0_7_p...           NaN
# 4   _roll_z_0_1_pris_y_0_1_pitch_x_0_1_pris_x_0_7_...           NaN
# ..                                                ...           ...
# 79  _roll_z_0_1_roll_y_0_3_pris_y_0_3_roll_x_0_1_p...           NaN
# 80  _roll_z_0_1_pris_z_0_3_pris_y_0_3_roll_y_0_1_p...           NaN
# 81  _roll_z_0_1_pris_y_0_3_roll_y_0_3_pitch_y_0_1_...           NaN
# 82  _roll_z_0_1_roll_y_0_3_pris_y_0_3_pitch_x_0_1_...           NaN
# 83  _roll_z_0_1_pitch_y_0_3_roll_x_0_1_pris_y_0_1_...           NaN
#
#     Move duration  Success  Manipulability - mu  Manipulability - jacobian  \
# ...

# %%
# new data frame with split value columns
new = problematic["Arm_ID"].str.split("_", expand=True)

problematic["Joint1 type"] = new[1]
problematic["Joint1 axis"] = new[2]
problematic["Link1 length"] = new[3] + "." + new[4]

problematic["Joint2 type"] = new[5]
problematic["Joint2 axis"] = new[6]
problematic["Link2 length"] = new[7] + "." + new[8]

problematic["Joint3 type"] = new[9]
problematic["Joint3 axis"] = new[10]
problematic["Link3 length"] = new[11] + "." + new[12]

problematic["Joint4 type"] = new[13]
problematic["Joint4 axis"] = new[14]
problematic["Link4 length"] = new[15] + "." + new[16]

problematic["Joint5 type"] = new[17]
problematic["Joint5 axis"] = new[18]
problematic["Link5 length"] = new[19] + "." + new[20]

problematic["Joint6 type"] = new[21]
problematic["Joint6 axis"] = new[22]
problematic["Link6 length"] = new[23] + "." + new[24]

#all_6dof_data = grouped_all_6dof_data.drop(['Arm_ID'], axis=1)

grouped_problematic = problematic.groupby(['Joint1 type','Joint1 axis', 'Joint2 type', 'Joint2 axis',
                                                      'Joint3 type', 'Joint3 axis', 'Joint4 type',
                                                      'Joint4 axis','Joint5 type', 'Joint5 axis','Joint6 type', 
                                           'Joint6 axis','Link1 length', 'Link2 length', 'Link3 length', 'Link4 length','Link5 length','Link6 length']).agg(
    Success_Rates=pd.NamedAgg(column="Success", aggfunc='mean'),
    Min_Manipulability=pd.NamedAgg(column='Manipulability - mu', aggfunc='min'),
    Max_Manipulability=pd.NamedAgg(column='Manipulability - mu', aggfunc='max'),
    Manipulability_Rates=pd.NamedAgg(column='Manipulability - mu', aggfunc='mean'),
    MaxSum_Mid_joint_proximity=pd.NamedAgg(column='Sum Mid joint proximity- all joints', aggfunc='max')).reset_index()

grouped_problematic

grouped_all = pd.concat([grouped_all,grouped_problematic]).reset_index()
grouped_all = grouped_all.drop(columns='index')
grouped_all
grouped_all.to_csv('all_link_families.csv')
grouped_all

# problematic
# Out:
#       Joint1 type Joint1 axis Joint2 type Joint2 axis Joint3 type Joint3 axis  \
# 0            roll           z       pitch           y       pitch           x
# 1            roll           z       pitch           y       pitch           x
# 2            roll           z       pitch           y       pitch           x
# 3            roll           z       pitch           y       pitch           x
# 4            roll           z       pitch           y       pitch           x
# ...           ...         ...         ...         ...         ...         ...
# 41011        roll           z        roll           y        pris           y
# 41012        roll           z        roll           y        pris           y
# 41013        roll           z        roll           y        pris           y
# 41014        roll           z        roll           y        pris           y
# 41015        roll           z        roll           y        pris           y
#
# ...

# %%
'''Indexing Link Configuration and Joint Confuguration'''
grouped_all['Joint Configuration Index'] = grouped_all.groupby(['Joint1 type','Joint1 axis', 'Joint2 type', 'Joint2 axis',
                                                      'Joint3 type', 'Joint3 axis', 'Joint4 type',
                                                      'Joint4 axis','Joint5 type', 'Joint5 axis','Joint6 type', 'Joint6 axis']).ngroup()


grouped_all['Link Configuration Index'] = grouped_all.groupby(['Link1 length', 'Link2 length', 'Link3 length', 'Link4 length','Link5 length','Link6 length']).ngroup()

grouped_all
# Out:
#       Joint1 type Joint1 axis Joint2 type Joint2 axis Joint3 type Joint3 axis  \
# 0            roll           z       pitch           y       pitch           x
# 1            roll           z       pitch           y       pitch           x
# 2            roll           z       pitch           y       pitch           x
# 3            roll           z       pitch           y       pitch           x
# 4            roll           z       pitch           y       pitch           x
# ...           ...         ...         ...         ...         ...         ...
# 41011        roll           z        roll           y        pris           y
# 41012        roll           z        roll           y        pris           y
# 41013        roll           z        roll           y        pris           y
# 41014        roll           z        roll           y        pris           y
# 41015        roll           z        roll           y        pris           y
#
# ...

# %% [markdown]
# # Group by Joint Configuration

# %%
'''Group by Joints Configurations
    Mean_Min_Manipulability - avarage of minimum manipulability
    MaxSum_Mid_joint_proximity - avarage of maximum sum of mid joint matrix
'''

joint_conf_6dof = grouped_all.groupby(['Joint1 type','Joint1 axis', 'Joint2 type', 'Joint2 axis',
                                                      'Joint3 type', 'Joint3 axis', 'Joint4 type',
                                                      'Joint4 axis','Joint5 type', 'Joint5 axis','Joint6 type', 'Joint6 axis']).agg(
    Joint_configuration_index = pd.NamedAgg(column='Joint Configuration Index', aggfunc='mean'),
    Success_Rates = pd.NamedAgg(column='Success_Rates', aggfunc='mean'),
    Mean_Min_Manipulability=pd.NamedAgg(column='Min_Manipulability', aggfunc='mean'),
    Mean_MaxSum_Mid_joint_proximity=pd.NamedAgg(column='MaxSum_Mid_joint_proximity', aggfunc='mean')).reset_index()


joint_conf_6dof['1-Mean_Min_Manipulability'] = 1 - joint_conf_6dof['Mean_Min_Manipulability']
x = joint_conf_6dof['Mean_MaxSum_Mid_joint_proximity']
y = joint_conf_6dof['1-Mean_Min_Manipulability']
h = joint_conf_6dof['Joint_configuration_index']

sns.scatterplot(x=x, y=y, hue=h)
plt.show()

joint_conf_6dof
# Out:
#      Joint1 type Joint1 axis Joint2 type Joint2 axis Joint3 type Joint3 axis  \
# 0           roll           z       pitch           y       pitch           x
# 1           roll           z       pitch           y       pitch           x
# 2           roll           z       pitch           y       pitch           x
# 3           roll           z       pitch           y       pitch           x
# 4           roll           z       pitch           y       pitch           x
# ...          ...         ...         ...         ...         ...         ...
# 6831        roll           z        roll           y        roll           y
# 6832        roll           z        roll           y        roll           y
# 6833        roll           z        roll           y        roll           y
# 6834        roll           z        roll           y        roll           y
# 6835        roll           z        roll           y        roll           y
#
# ...

# %% [markdown]
# # Group by Link Configuration

# %%
'''Group by Links Configurations
    Mean_Min_Manipulability - avarage of minimum manipulability
    MaxSum_Mid_joint_proximity - avarage of maximum sum of mid joint matrix
'''
links_conf_6dof = grouped_all.groupby(
    ['Link1 length', 'Link2 length', 'Link3 length', 'Link4 length','Link5 length','Link6 length']).agg(
    Link_configuration_index= pd.NamedAgg(column='Link Configuration Index', aggfunc='mean'),
    Success_Rates = pd.NamedAgg(column='Success_Rates', aggfunc='mean'),
    Mean_Min_Manipulability=pd.NamedAgg(column='Min_Manipulability', aggfunc='mean'),
    Mean_MaxSum_Mid_joint_proximity=pd.NamedAgg(column='MaxSum_Mid_joint_proximity', aggfunc='mean')).reset_index()



links_conf_6dof
# Out:
#   Link1 length Link2 length Link3 length Link4 length Link5 length  \
# 0          0.1          0.1          0.1          0.7          0.1
# 1          0.1          0.1          0.3          0.5          0.1
# 2          0.1          0.1          0.3          0.7          0.3
# 3          0.1          0.3          0.1          0.1          0.5
# 4          0.1          0.3          0.3          0.1          0.7
# 5          0.1          0.7          0.5          0.3          0.1
#
#   Link6 length  Link_configuration_index  Success_Rates  \
# 0          0.3                       0.0       0.123137
# 1          0.3                       1.0       0.145774
# 2          0.1                       2.0       0.169827
# 3          0.3                       3.0       0.099883
# 4          0.5                       4.0       0.101574
# 5          0.3                       5.0       0.172489
#
#    Mean_Min_Manipulability  Mean_MaxSum_Mid_joint_proximity
# ...
