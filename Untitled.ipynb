# %%
import pandas as pd

# %%
dataset = pd.read_csv('6dof_dataset.csv')
grouped = pd.read_csv('6dof_grouped.csv')
grouped_dummis = pd.read_csv('6dof_grouped_dummied.csv')
classification = pd.read_csv('6dof_classification.csv')

# %%
dataset
# Out:
#          Unnamed: 0                                             Arm_ID  \
# 0                 0  _roll_z_0_1_pitch_y_0_3_pris_z_0_1_pris_y_0_7_...
# 1                 1  _roll_z_0_1_pitch_y_0_3_pris_z_0_1_pris_y_0_7_...
# 2                 2  _roll_z_0_1_pitch_y_0_3_pris_z_0_1_pris_y_0_7_...
# 3                 3  _roll_z_0_1_pitch_y_0_3_pris_z_0_1_pris_y_0_7_...
# 4                 4  _roll_z_0_1_pitch_y_0_3_pris_z_0_1_pris_y_0_7_...
# ...             ...                                                ...
# 1025395     1025395  _roll_z_0_1_roll_y_0_7_pris_z_0_5_pris_y_0_1_r...
# 1025396     1025396  _roll_z_0_1_roll_y_0_7_pris_z_0_5_pris_y_0_1_r...
# 1025397     1025397  _roll_z_0_1_roll_y_0_7_pris_z_0_5_pris_y_0_1_r...
# 1025398     1025398  _roll_z_0_1_roll_y_0_7_pris_z_0_5_pris_y_0_1_r...
# 1025399     1025399  _roll_z_0_1_roll_y_0_7_pris_z_0_5_pris_y_0_1_r...
#
#          Point number  Move duration  Success  Manipulability - mu  \
# ...

# %%
grouped
# Out:
#         Unnamed: 0 Joint1 type Joint1 axis Joint2 type Joint2 axis  \
# 0                0        roll           z       pitch           y
# 1                1        roll           z       pitch           y
# 2                2        roll           z       pitch           y
# 3                3        roll           z       pitch           y
# 4                4        roll           z       pitch           y
# ...            ...         ...         ...         ...         ...
# 102535      102535        roll           z        roll           y
# 102536      102536        roll           z        roll           y
# 102537      102537        roll           z        roll           y
# 102538      102538        roll           z        roll           y
# 102539      102539        roll           z        roll           y
#
#        Joint3 type Joint3 axis Joint4 type Joint4 axis Joint5 type  ...  \
# 0            pitch           x       pitch           x       pitch  ...
# ...

# %%
grouped_dummis
# Out:
#         Unnamed: 0  Link1 length  Link2 length  Link3 length  Link4 length  \
# 0                0           0.1           0.1           0.1           0.3
# 1                1           0.1           0.1           0.3           0.3
# 2                2           0.1           0.1           0.5           0.1
# 3                3           0.1           0.1           0.5           0.3
# 4                4           0.1           0.3           0.1           0.1
# ...            ...           ...           ...           ...           ...
# 102535      102535           0.1           0.5           0.1           0.7
# 102536      102536           0.1           0.5           0.7           0.3
# 102537      102537           0.1           0.7           0.3           0.1
# 102538      102538           0.1           0.7           0.3           0.1
# 102539      102539           0.1           0.7           0.3           0.3
#
# ...

# %%
classification
# Out:
#         Unnamed: 0  Link2 length  Link3 length  Link4 length  Link5 length  \
# 0                0           0.1           0.1           0.1           0.3
# 1                1           0.1           0.1           0.1           0.5
# 2                2           0.1           0.1           0.1           0.7
# 3                3           0.1           0.1           0.1           0.7
# 4                4           0.1           0.1           0.1           0.7
# ...            ...           ...           ...           ...           ...
# 102535      102535           0.7           0.7           0.3           0.1
# 102536      102536           0.7           0.7           0.1           0.1
# 102537      102537           0.7           0.7           0.3           0.1
# 102538      102538           0.7           0.7           0.1           0.1
# 102539      102539           0.7           0.7           0.1           0.3
#
# ...

# %%
discritization_and_classification = pd.get_dummies(classification, columns=['Link2 length', 'Link3 length','Link4 length','Link5 length','Link6 length'])

discritization_and_classification.drop(columns='Unnamed: 0',inplace=True)
discritization_and_classification.to_csv('disc_and_classification.csv')
